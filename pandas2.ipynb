# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][1:11]
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
list(df['Name'][1:11])
# Out:
# ['Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut']

# %%
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.loc['Futrelle, Mrs. Jacques Heath (Lily May Peel)']
# Out:
# Survived         1
# Pclass           1
# Sex         female
# Age           35.0
# SibSp            1
# Parch            0
# Ticket      113803
# Fare          53.1
# Cabin         C123
# Embarked         S
# Name: Futrelle, Mrs. Jacques Heath (Lily May Peel), dtype: object

# %%
df.iloc[2]
# Out:
# Survived                   1
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
df.reset_index(inplace=True)

# %%
d={"key1":[1,3,5,6],
  "key2":[6,7,8,0],
  "key3":[7,4,3,1]}

# %%
d
# Out:
# {'key1': [1, 3, 5, 6], 'key2': [6, 7, 8, 0], 'key3': [7, 4, 3, 1]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6     7
# 1     3     7     4
# 2     5     8     3
# 3     6     0     1

# %%
d1={"key1":(1,3,5,6),
  "key4":(6,7,8,0),
  "key5":(7,4,3,1)}

# %%
pd.DataFrame(d1)
# Out:
#    key1  key4  key5
# 0     1     6     7
# 1     3     7     4
# 2     5     8     3
# 3     6     0     1

# %%
l=['a','b','c']

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.isnull()
# Out:
#       Name  Survived  Pclass    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0    False     False   False  False  False  False  False   False  False
# 1    False     False   False  False  False  False  False   False  False
# 2    False     False   False  False  False  False  False   False  False
# 3    False     False   False  False  False  False  False   False  False
# 4    False     False   False  False  False  False  False   False  False
# ..     ...       ...     ...    ...    ...    ...    ...     ...    ...
# 886  False     False   False  False  False  False  False   False  False
# 887  False     False   False  False  False  False  False   False  False
# 888  False     False   False  False   True  False  False   False  False
# 889  False     False   False  False  False  False  False   False  False
# 890  False     False   False  False  False  False  False   False  False
#
#      Cabin  Embarked
# 0     True     False
# 1    False     False
# 2     True     False
# ...

# %%
df.isnull().count()
# Out:
# Name        891
# Survived    891
# Pclass      891
# Sex         891
# Age         891
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       891
# Embarked    891
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name          0
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df1=pd.read_csv("taxonomy.csv.xls")
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.isnull()
# Out:
#      taxonomy_id   name  parent_id  parent_name
# 0          False  False       True         True
# 1          False  False      False        False
# 2          False  False      False        False
# 3          False  False      False        False
# 4          False  False      False        False
# ..           ...    ...        ...          ...
# 285        False  False      False        False
# 286        False  False      False        False
# 287        False  False      False        False
# 288        False  False      False        False
# 289        False  False      False        False
#
# [290 rows x 4 columns]

# %%
df1.dropna(axis=0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# taxonomy_id    0
# name           0
# parent_id      0
# parent_name    0
# dtype: int64

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.groupby("Survived").mean()
# Out:
# /tmp/ipykernel_88/2030998582.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Survived").mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df.groupby('Sex').sum()
# Out:
# /tmp/ipykernel_88/3906318127.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').sum()
#         Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       233     678   7286.00    218    204  13966.6628
# male         109    1379  13919.17    248    136  14727.2865

# %%
df.groupby('Sex').sum()['Age']
# Out:
# /tmp/ipykernel_88/598500297.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').sum()['Age']
# Sex
# female     7286.00
# male      13919.17
# Name: Age, dtype: float64

# %%
df.groupby('Sex').sum()['Fare']
# Out:
# /tmp/ipykernel_88/1272871990.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').sum()['Fare']
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass').sum()
# Out:
# /tmp/ipykernel_88/1406034237.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Pclass').sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            136  7111.42     90     77  18177.4125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
df.T
# Out:
#                               0    \
# Name      Braund, Mr. Owen Harris
# Survived                        0
# Pclass                          3
# Sex                          male
# Age                          22.0
# SibSp                           1
# Parch                           0
# Ticket                  A/5 21171
# Fare                         7.25
# Cabin                         NaN
# Embarked                        S
#
#                                                         1    \
# Name      Cumings, Mrs. John Bradley (Florence Briggs Th...
# Survived                                                  1
# Pclass                                                    1
# Sex                                                  female
# Age                                                    38.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                             PC 17599
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
dfa=df[['Name','Survived','Pclass','Sex']].head()
dfa
# Out:
#                                                 Name  Survived  Pclass     Sex
# 0                            Braund, Mr. Owen Harris         0       3    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1  female
# 2                             Heikkinen, Miss. Laina         1       3  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 4                           Allen, Mr. William Henry         0       3    male

# %%
dfb=df[['Name','Survived','Pclass','Sex']][5:11]
dfb
# Out:
#                                                  Name  Survived  Pclass  \
# 5                                    Moran, Mr. James         0       3
# 6                             McCarthy, Mr. Timothy J         0       1
# 7                      Palsson, Master. Gosta Leonard         0       3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 10                    Sandstrom, Miss. Marguerite Rut         1       3
#
#        Sex
# 5     male
# 6     male
# 7     male
# 8   female
# 9   female
# 10  female

# %%
pd.concat([dfa,dfb])
# Out:
#                                                  Name  Survived  Pclass  \
# 0                             Braund, Mr. Owen Harris         0       3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                              Heikkinen, Miss. Laina         1       3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                            Allen, Mr. William Henry         0       3
# 5                                    Moran, Mr. James         0       3
# 6                             McCarthy, Mr. Timothy J         0       1
# 7                      Palsson, Master. Gosta Leonard         0       3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 10                    Sandstrom, Miss. Marguerite Rut         1       3
#
#        Sex
# 0     male
# 1   female
# 2   female
# 3   female
# 4     male
# 5     male
# 6     male
# ...

# %%
data1=pd.DataFrame(d)
data1
# Out:
#    key1  key2  key3
# 0     1     6     7
# 1     3     7     4
# 2     5     8     3
# 3     6     0     1

# %%
data2=pd.DataFrame(d1)
data2
# Out:
#    key1  key4  key5
# 0     1     6     7
# 1     3     7     4
# 2     5     8     3
# 3     6     0     1

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     7     6     7
# 1     3     7     4     7     4
# 2     5     8     3     8     3
# 3     6     0     1     0     1

# %%
pd.merge(data1,data2,how="left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     7     6     7
# 1     3     7     4     7     4
# 2     5     8     3     8     3
# 3     6     0     1     0     1

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     7     6     7
# 1     3     7     4     7     4
# 2     5     8     3     8     3
# 3     6     0     1     0     1

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     6     7       1     6     7
# 1        1     6     7       3     7     4
# 2        1     6     7       5     8     3
# 3        1     6     7       6     0     1
# 4        3     7     4       1     6     7
# 5        3     7     4       3     7     4
# 6        3     7     4       5     8     3
# 7        3     7     4       6     0     1
# 8        5     8     3       1     6     7
# 9        5     8     3       3     7     4
# 10       5     8     3       5     8     3
# 11       5     8     3       6     0     1
# 12       6     0     1       1     6     7
# 13       6     0     1       3     7     4
# 14       6     0     1       5     8     3
# 15       6     0     1       6     0     1

# %%
d3=pd.DataFrame({"key1":[1,3,5,6],
  "key2":[6,7,8,0],
  "key3":[7,4,3,1]},index=['a','b','c','d'])
d3
# Out:
#    key1  key2  key3
# a     1     6     7
# b     3     7     4
# c     5     8     3
# d     6     0     1

# %%
d4=pd.DataFrame({"key4":(4,65,67,8),
  "key5":(2,9,7,0),
  "key6":(98,12,35,67)},index=['a','b','o','j'])
d4
# Out:
#    key4  key5  key6
# a     4     2    98
# b    65     9    12
# o    67     7    35
# j     8     0    67

# %%
d3.join(d4)
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     7   4.0   2.0  98.0
# b     3     7     4  65.0   9.0  12.0
# c     5     8     3   NaN   NaN   NaN
# d     6     0     1   NaN   NaN   NaN

# %%
d3.join(d4,how="inner")
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     7     4     2    98
# b     3     7     4    65     9    12

# %%
d3.join(d4,how='left')
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     7   4.0   2.0  98.0
# b     3     7     4  65.0   9.0  12.0
# c     5     8     3   NaN   NaN   NaN
# d     6     0     1   NaN   NaN   NaN

# %%
d3.join(d4,how='right')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   6.0   7.0     4     2    98
# b   3.0   7.0   4.0    65     9    12
# o   NaN   NaN   NaN    67     7    35
# j   NaN   NaN   NaN     8     0    67

# %%
d3.join(d4,how='cross')
# Out:
#     key1  key2  key3  key4  key5  key6
# 0      1     6     7     4     2    98
# 1      1     6     7    65     9    12
# 2      1     6     7    67     7    35
# 3      1     6     7     8     0    67
# 4      3     7     4     4     2    98
# 5      3     7     4    65     9    12
# 6      3     7     4    67     7    35
# 7      3     7     4     8     0    67
# 8      5     8     3     4     2    98
# 9      5     8     3    65     9    12
# 10     5     8     3    67     7    35
# 11     5     8     3     8     0    67
# 12     6     0     1     4     2    98
# 13     6     0     1    65     9    12
# 14     6     0     1    67     7    35
# 15     6     0     1     8     0    67

# %%
d3.join(d4,how='outer')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   6.0   7.0   4.0   2.0  98.0
# b   3.0   7.0   4.0  65.0   9.0  12.0
# c   5.0   8.0   3.0   NaN   NaN   NaN
# d   6.0   0.0   1.0   NaN   NaN   NaN
# j   NaN   NaN   NaN   8.0   0.0  67.0
# o   NaN   NaN   NaN  67.0   7.0  35.0

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df['fare_inr']=df['Fare'].apply(lambda x:x*80)
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
def con_inr(x):
    return x*80
df['fare_inr']=df['Fare'].apply(con_inr)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    fare_inr
# 0   580.000
# 1  5702.664
# 2   634.000
# 3  4248.000
# 4   644.000

# %%
df['name_len']=df['Name'].apply(len)
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    fare_inr  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# ...

# %%
def flag_fare(x):
    if x<10:
        return 'cheap'
    elif (x>10) & (x<20):
        return 'mid'
    else:
        return 'high'
df['fare_cat']=df['Fare'].apply(flag_fare)

df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...
